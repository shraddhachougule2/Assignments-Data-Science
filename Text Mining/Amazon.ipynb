# %%
import requests
from bs4 import BeautifulSoup

# %%
def get_soup(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup

# %%
review_list = []
def get_reviews(soup):
    reviews = soup.find_all('div', {'data-hook': 'review'})
    try:
        for i in reviews:
            review  = i.find('span', {'data-hook': 'review-body'}).text.strip()    
            review_list.append(review)
    except:
        pass

# %%
for x in range(1,400):
    soup = get_soup(f'https://www.amazon.in/Boult-Audio-AirBass-Wireless-Bluetooth/product-reviews/B092VR6WYC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews={x}')
    get_reviews(soup)
    print(len(review_list))
    if not soup.find('li', {'class': 'a-disabled a-last'}):
        pass
    else:
        break
# Out:
# 10
# 20
# 30
# 40
# 40
# 50
# 60
# 70
# 80
# 90
# 100
# 110
# 120
# 130
# 140
# 150
# 160
# 160
# 170
# 180
# 190
# 190
# 200
# 210
# 220
# 230
# 240
# 240
# 240
# 250
# 260
# 260
# 260
# 260
# 260
# 270
# 280
# 290
# 290
# 300
# 300
# 300
# 300
# 300
# 310
# 320
# 330
# 330
# 340
# 350
# 360
# 360
# 370
# 380
# 380
# 390
# 390
# 400
# 410
# 410
# 420
# 420
# 420
# 430
# 430
# 440
# 440
# 440
# 450
# 460
# 470
# 480
# 490
# 500
# 500
# 510
# 520
# 520
# 530
# 540
# 550
# 550
# 560
# 570
# 580
# 590
# 600
# 610
# 610
# 620
# 630
# 640
# 650
# 660
# 660
# 660
# 660
# 670
# 680
# 690
# 690
# 690
# 700
# 710
# 720
# 730
# 730
# 740
# 750
# 760
# 760
# 770
# 780
# 790
# 790
# 800
# 810
# 820
# 830
# 840
# 850
# 860
# 870
# 880
# 890
# 900
# 900
# 900
# 910
# 920
# 920
# 930
# 940
# 950
# 960
# 970
# 980
# 980
# 990
# 990
# 1000
# 1010
# 1020
# 1020
# 1030
# 1040
# 1040
# 1040
# 1050
# 1060
# 1070
# 1070
# 1070
# 1070
# 1070
# 1070
# 1080
# 1090
# 1100
# 1110
# 1120
# 1130
# 1140
# 1150
# ...

# %%
import pandas as pd

df = pd.DataFrame(review_list, columns = ['Reviews'])
df
# Out:
#                                                 Reviews
# 0     Hello Everyone.I am using the headphones for t...
# 1     Pros~ ∆Sound quality ∆Battery life and quick c...
# 2     Sir boult audio fx1 left side not working plea...
# 3                                                  Nice
# 4     Reviewing it after my replacement order. First...
# ...                                                 ...
# 2725                                               nice
# 2726  One week once I’m  charging. It’s really good ...
# 2727                             I like it this product
# 2728  The media could not be loaded.\n              ...
# 2729  I didn't really use it yet...i don't know it's...
#
# [2730 rows x 1 columns]

# %%
df.to_csv('product_reviews.csv', index = False)
